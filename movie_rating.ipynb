# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\ZAFAR ANSARI\Downloads\archive (1)\merged_dataset.csv")
data
# Out:
#                                                    name  year movie_rated  \
# 0                                             Inception  2010       PG-13
# 1     The Lord of the Rings: The Fellowship of the Ring  2001       PG-13
# 2         The Lord of the Rings: The Return of the King  2003       PG-13
# 3                                 The Dark Knight Rises  2012       PG-13
# 4                 The Lord of the Rings: The Two Towers  2002       PG-13
# ...                                                 ...   ...         ...
# 1495                                           Catch-22  1970           R
# 1496                                     The Great Raid  2005           R
# 1497                                Saints and Soldiers  2003       PG-13
# 1498                                          Stop-Loss  2008           R
# 1499                                          The Alamo  2004       PG-13
#
#      run_length                       genres            release_date  rating  \
# ...

# %%
data.isnull().sum()
# Out:
# name            0
# year            0
# movie_rated     0
# run_length      0
# genres          0
# release_date    0
# rating          0
# num_raters      0
# num_reviews     0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# 1499    False
# Length: 1500, dtype: bool

# %%
data
# Out:
#                                                    name  year movie_rated  \
# 0                                             Inception  2010       PG-13
# 1     The Lord of the Rings: The Fellowship of the Ring  2001       PG-13
# 2         The Lord of the Rings: The Return of the King  2003       PG-13
# 3                                 The Dark Knight Rises  2012       PG-13
# 4                 The Lord of the Rings: The Two Towers  2002       PG-13
# ...                                                 ...   ...         ...
# 1495                                           Catch-22  1970           R
# 1496                                     The Great Raid  2005           R
# 1497                                Saints and Soldiers  2003       PG-13
# 1498                                          Stop-Loss  2008           R
# 1499                                          The Alamo  2004       PG-13
#
#      run_length                       genres            release_date  rating  \
# ...

# %%
data['release_date'].str.split(pat = '(')
# Out:
# 0           [16 July 2010 , USA)]
# 1       [19 December 2001 , USA)]
# 2       [17 December 2003 , USA)]
# 3           [20 July 2012 , USA)]
# 4       [18 December 2002 , USA)]
#                   ...
# 1495        [24 June 1970 , USA)]
# 1496      [12 August 2005 , USA)]
# 1497       [25 March 2005 , USA)]
# 1498       [28 March 2008 , USA)]
# 1499        [9 April 2004 , USA)]
# Name: release_date, Length: 1500, dtype: object

# %%
data["Country"] = data ["release_date"].str.split(pat = '(').str[1]

# %%
data["Country"] = data ["Country"].str.split(pat =')').str[0]

# %%
data["Country"]
# Out:
# 0       USA
# 1       USA
# 2       USA
# 3       USA
# 4       USA
#        ...
# 1495    USA
# 1496    USA
# 1497    USA
# 1498    USA
# 1499    USA
# Name: Country, Length: 1500, dtype: object

# %%
data['release_date'] = data['release_date'].str.split(pat = '(').str[0]

# %%
data.tail()
# Out:
#                      name  year movie_rated run_length                 genres  \
# 1495             Catch-22  1970           R    2h 2min   Comedy; Drama; War;
# 1496       The Great Raid  2005           R   2h 12min   Action; Drama; War;
# 1497  Saints and Soldiers  2003       PG-13   1h 30min   Action; Drama; War;
# 1498            Stop-Loss  2008           R   1h 52min           Drama; War;
# 1499            The Alamo  2004       PG-13   2h 17min  Drama; History; War;
#
#          release_date  rating  num_raters  num_reviews Country
# 1495    24 June 1970      7.1       21424          145     USA
# 1496  12 August 2005      6.7       20965          194     USA
# 1497   25 March 2005      6.7       19730          163     USA
# 1498   28 March 2008      6.4       19456          102     USA
# 1499    9 April 2004      6.0       19290          306     USA

# %%
min_r = data["year"].min()
max_r = data["year"].max()

# %%
min_r,max_r
# Out:
# (1915, 2020)

# %%
range  = max_r - min_r

# %%
range
# Out:
# 105

# %%
md = np.median(data['rating'])

# %%
mn = data["rating"].mean()

# %%
mo = data["rating"].mode()[0]

# %%
mn ,md, mo
# Out:
# (7.477600000000001, 7.6, 8.0)

# %%
data["year"].value_counts()
# Out:
# year
# 2013    73
# 2007    71
# 2004    70
# 2014    69
# 2011    65
#         ..
# 1973     1
# 1925     1
# 1950     1
# 1969     1
# 1915     1
# Name: count, Length: 80, dtype: int64

# %%
data["rating"].value_counts()
# Out:
# rating
# 8.0    107
# 7.7    103
# 7.6     94
# 8.1     93
# 7.3     85
# 7.8     80
# 7.0     72
# 7.4     62
# 7.9     61
# 7.2     61
# 7.5     61
# 6.9     59
# 8.3     55
# 8.2     49
# 6.8     45
# 6.6     42
# 7.1     41
# 8.5     40
# 6.7     38
# 8.4     35
# 6.4     33
# 6.5     31
# 8.6     26
# 6.2     20
# 6.3     16
# 8.9     11
# 6.1     10
# 8.7     10
# 6.0      8
# 5.9      8
# 8.8      7
# 5.8      6
# 5.6      5
# 9.0      4
# 5.2      3
# 5.7      3
# 5.0      3
# 9.2      2
# 5.4      2
# 4.1      2
# 9.3      1
# 4.7      1
# 5.5      1
# 4.9      1
# 5.3      1
# 3.5      1
# 4.5      1
# Name: count, dtype: int64

# %%
mny = data["year"].mean()
mny
# Out:
# 2002.632

# %%
sns.histplot(x='year',data=data)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(x='rating', y='name', data=data)
plt.yscale('log')
plt.show()

# %%
top_movie = data.nlargest(10, 'rating')


plt.figure(figsize=(10, 5))
sns.barplot(x='rating', y='name', data=top_movie, palette='viridis')
plt.title('Top 10 movie by rating')
plt.xlabel('rating')
plt.ylabel('movies')
plt.show()
# Out:
# C:\Users\ZAFAR ANSARI\AppData\Local\Temp\ipykernel_25800\224411110.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='rating', y='name', data=top_movie, palette='viridis')

# %%
top_movie = data.nlargest(10, 'rating')
plt.figure(figsize=(10, 6))
sns.histplot(data['rating'], kde=True, bins=20, color='blue')
plt.title('Distribution of rating')
plt.xlabel('rating')
plt.ylabel('Frequency')
plt.show()

# %%
top_rating = data.nlargest(10, 'rating')
plt.figure(figsize=(8, 5))
sns.countplot(x='rating', data=top_rating)
plt.yscale('log')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='rating',y='year',data=data, hue='rating',size='rating',sizes=(20, 200))
plt.show()

# %%
sns.scatterplot(x='rating',y='num_raters', data = data)
# Out:
# <Axes: xlabel='rating', ylabel='num_raters'>
